# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/andrewacosta'

# %%
fifa=pd.read_csv('/Users/andrewacosta/data_mid_bootcamp_project_FIFA_MoneyBall/fifa21_male2.csv')
# Out:
# /var/folders/km/hfy5z0x91fq61kjr6rswz7q00000gn/T/ipykernel_52036/3230246937.py:1: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa=pd.read_csv('/Users/andrewacosta/data_mid_bootcamp_project_FIFA_MoneyBall/fifa21_male2.csv')

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                           Club Logo  \
# ...

# %%
fifa.shape
# Out:
# (17125, 107)

# %%
fifa.drop('Club Logo', axis=1, inplace=True)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  POT            Team & Contract  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  POT            Team & Contract  \
# ...

# %%
fifa.info
# Out:
# <bound method DataFrame.info of            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# ...

# %%
fifa.dtypes
# Out:
# ID              int64
# Name           object
# Age             int64
# OVA             int64
# Nationality    object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# Gender         object
# Length: 106, dtype: object

# %%
fifa.isnull().sum()
# Out:
# ID             0
# Name           0
# Age            0
# OVA            0
# Nationality    0
#               ..
# CB             0
# RCB            0
# RB             0
# GK             0
# Gender         0
# Length: 106, dtype: int64

# %%
fifa.corr()
# Out:
#                         ID       Age       OVA       BOV       POT    Growth  \
# ID                1.000000 -0.743844 -0.431079 -0.385713  0.042604  0.553757
# Age              -0.743844  1.000000  0.517099  0.456734 -0.237619 -0.850204
# OVA              -0.431079  0.517099  1.000000  0.985877  0.592268 -0.595585
# BOV              -0.385713  0.456734  0.985877  1.000000  0.628323 -0.542890
# POT               0.042604 -0.237619  0.592268  0.628323  1.000000  0.294499
# Growth            0.553757 -0.850204 -0.595585 -0.542890  0.294499  1.000000
# Attacking        -0.178002  0.183954  0.431238  0.464329  0.233866 -0.278316
# Crossing         -0.152858  0.151022  0.386334  0.400046  0.210944 -0.247910
# Finishing        -0.110723  0.105311  0.304012  0.336488  0.173281 -0.187820
# Heading Accuracy -0.148036  0.172793  0.305553  0.335677  0.137199 -0.225620
# Short Passing    -0.173987  0.176786  0.492372  0.533046  0.318544 -0.266404
# ...

# %%
fifa.isna().sum()/len(fifa)*100
# Out:
# ID             0.0
# Name           0.0
# Age            0.0
# OVA            0.0
# Nationality    0.0
#               ...
# CB             0.0
# RCB            0.0
# RB             0.0
# GK             0.0
# Gender         0.0
# Length: 106, dtype: float64

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  POT            Team & Contract  \
# ...

# %%
fifa.describe()
# Out:
#                   ID           Age           OVA           BOV           POT  \
# count   17125.000000  17125.000000  17125.000000  17125.000000  17125.000000
# mean   219388.716204     25.272934     66.965022     67.900204     72.489810
# std     37499.197507      4.942665      6.864329      6.637538      5.769949
# min         2.000000     16.000000     38.000000     42.000000     47.000000
# 25%    204082.000000     21.000000     62.000000     64.000000     69.000000
# 50%    228961.000000     25.000000     67.000000     68.000000     72.000000
# 75%    243911.000000     29.000000     72.000000     72.000000     76.000000
# max    259105.000000     53.000000     93.000000     93.000000     95.000000
#
#              Growth     Attacking      Crossing     Finishing  \
# count  17125.000000  17125.000000  17125.000000  17125.000000
# mean       5.524788    258.537752     51.621314     47.956672
# std        5.787539     72.255687     17.875715     19.391547
# ...

# %%
fifa.drop(fifa.loc[:, 'Nationality' : 'Flag Photo'].columns, axis=1, inplace=True)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA  POT            Team & Contract Height  Weight  \
# 0   2  G. Pasquale   33   69   69        Udinese 2008 ~ 2016   6'0"  181lbs
# 1  16  Luis García   37   71   71      KAS Eupen 2014 ~ 2019  5'10"  143lbs
# 2  27      J. Cole   33   71   71  Coventry City 2016 ~ 2020   5'9"  161lbs
# 3  36     D. Yorke   36   68   82            Sunderland 2009  5'11"  165lbs
# 4  41      Iniesta   36   81   81    Vissel Kobe 2018 ~ 2021   5'7"  150lbs
#
#     foot  Growth        Joined Loan Date End  Value  Wage Release Clause  \
# 0   Left       0   Jul 1, 2008           NaN  €625K   €7K             €0
# 1  Right       0  Jul 19, 2014           NaN  €600K   €7K          €1.1M
# 2  Right       0   Jan 7, 2016           NaN  €1.1M  €15K             €0
# 3  Right      14           NaN           NaN     €0    €0             €0
# 4  Right       0  Jul 16, 2018           NaN  €5.5M  €12K          €7.2M
#
#       Contract  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
fifa.drop(fifa.loc[:, 'Team & Contract' : 'GK Reflexes'].columns, axis=1, inplace=True)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA  POT  Total Stats  Base Stats  W/F  SM     A/W  \
# 0   2  G. Pasquale   33   69   69         1929         408  3 ★  2★  Medium
# 1  16  Luis García   37   71   71         1906         385  4 ★  3★  Medium
# 2  27      J. Cole   33   71   71         1770         354  4 ★  4★  Medium
# 3  36     D. Yorke   36   68   82         1348         369  3 ★  1★     NaN
# 4  41      Iniesta   36   81   81         2014         420  4 ★  4★    High
#
#       D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS    LW  \
# 0    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0  68+0
# 1  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1  67+0
# 2     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0  70+0
# 3     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0  66+0
# 4  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3  79+0
#
# ...

# %%
fifa.drop(fifa.loc[:, 'W/F' :].columns, axis=1, inplace=True)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA  POT  Total Stats  Base Stats
# 0   2  G. Pasquale   33   69   69         1929         408
# 1  16  Luis García   37   71   71         1906         385
# 2  27      J. Cole   33   71   71         1770         354
# 3  36     D. Yorke   36   68   82         1348         369
# 4  41      Iniesta   36   81   81         2014         420

# %%
import seaborn as sns

# %%
sns.relplot(x='OVA', y='Age', data=fifa)

# %%
sns.relplot(x='OVA', y='POT', data=fifa)

# %%
sns.relplot(x='OVA', y='Total Stats', data=fifa)

# %%
sns.relplot(x='OVA', y='Base Stats', data=fifa)

# %%
fifa.head()
# Out:
#    ID         Name  Age  OVA  POT  Total Stats  Base Stats
# 0   2  G. Pasquale   33   69   69         1929         408
# 1  16  Luis García   37   71   71         1906         385
# 2  27      J. Cole   33   71   71         1770         354
# 3  36     D. Yorke   36   68   82         1348         369
# 4  41      Iniesta   36   81   81         2014         420

# %%
fifa.dtypes
# Out:
# ID              int64
# Name           object
# Age             int64
# OVA             int64
# POT             int64
# Total Stats     int64
# Base Stats      int64
# dtype: object

# %%
fifa.isnull().sum()
# Out:
# ID             0
# Name           0
# Age            0
# OVA            0
# POT            0
# Total Stats    0
# Base Stats     0
# dtype: int64

# %%
fifa.corr()
# Out:
#                    ID       Age       OVA       POT  Total Stats  Base Stats
# ID           1.000000 -0.743844 -0.431079  0.042604    -0.236634   -0.339341
# Age         -0.743844  1.000000  0.517099 -0.237619     0.280383    0.414897
# OVA         -0.431079  0.517099  1.000000  0.592268     0.607676    0.832618
# POT          0.042604 -0.237619  0.592268  1.000000     0.329178    0.474763
# Total Stats -0.236634  0.280383  0.607676  0.329178     1.000000    0.678885
# Base Stats  -0.339341  0.414897  0.832618  0.474763     0.678885    1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = fifa.drop(['OVA', 'ID', 'Name'], axis=1)
test = fifa['OVA']

# %%
X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.3, random_state=0)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pre=lr.predict(X_test)

# %%
pre
# Out:
# array([65.81405742, 61.81931424, 73.56628497, ..., 49.54303265,
#        56.86286545, 63.53715011])

# %%
lr.score(X_test, y_test)
# Out:
# 0.8805294138106684
